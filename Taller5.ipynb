# %%
print("hola mundo")
# Out:
# hola mundo

# %%
nombre = "Miguel"
print(nombre)
# Out:
# Miguel

# %%
print("hola mundo soy miguel")

# %%
print(80+120)
# Out:
# 200

# %%
print(90-14)

# %%
print(8*9)
# Out:
# 72

# %%
print(9/3)
# Out:
# 3.0
